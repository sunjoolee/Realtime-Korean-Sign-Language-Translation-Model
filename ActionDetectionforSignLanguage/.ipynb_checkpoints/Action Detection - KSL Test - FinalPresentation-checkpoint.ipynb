# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install opencv-python mediapipe scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\envs\tf\lib\site-packages (4.7.0.72)
# Requirement already satisfied: mediapipe in c:\programdata\anaconda3\envs\tf\lib\site-packages (0.10.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\envs\tf\lib\site-packages (1.2.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\tf\lib\site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: absl-py in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (23.5.9)
# Requirement already satisfied: opencv-contrib-python in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (4.7.0.72)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\envs\tf\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model): 
    #image = feed frame
    #model = Holistic model
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR -> RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB -> BGR
    return image, results

# %%
#connection_drawing_spec 커스텀 (optional)
def draw_styled_landmarks(image, results):
    #Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# # 3. Extract Keypoint Values
# results의 landmarks값 -> numpy array로 변환하기

# %%
def extract_keypoints(results):
    # result의 landmarks의 모든 key point values -> 하나의 numpy array 로 flatten
    #if landmarks has no value, fill numpy array with zero
    
    if results.pose_landmarks: #pose landmarks
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() 
    else:
        pose = np.zeros(132) #33*4

    if results.left_hand_landmarks: #left hand landmarks
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() 
    else:
        lh = np.zeros(63) #21*3

    if results.right_hand_landmarks: #right hand landmarks
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() 
    else:
        rh = np.zeros(63) #21*3
    
    #return np.concatenate([pose, lh, rh])
    return np.concatenate([pose, lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
#pandas
# !pip install xlrd
# !pip install openpyxl
# !pip install pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xlrd in c:\users\user\appdata\roaming\python\python39\site-packages (2.0.1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\users\user\appdata\roaming\python\python39\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\user\appdata\roaming\python\python39\site-packages (from openpyxl) (1.1.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python39\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
#데이터 레이블 정보가 담긴 엑셀 파일
annotation_file_name = 'KETI-2018-SL-Annotation-v1.xlsx'

#엑셀 파일 데이터 프레임에 읽어오기
df = pd.read_excel(
    annotation_file_name, 
    sheet_name = 'KETI-2018-수어데이터-학습용-Annotation')

#단어 데이터만 필터링
df = df[df['타입(단어/문장)']=='단어']
#필요한 열만 추출
df = df.filter(items=['파일명', '한국어'], axis=1)
#모든 열 string 타입으로 변경
df = df.astype({'파일명':'string'},{'한국어':'string'})

print(df)
# Out:
#                       파일명  한국어
# 0      KETI_SL_0000010481    0
# 1      KETI_SL_0000010482    1
# 2      KETI_SL_0000010483    2
# 3      KETI_SL_0000010484    3
# 4      KETI_SL_0000010485    4
# ...                   ...  ...
# 26392  KETI_SL_0000036873   화상
# 26393  KETI_SL_0000036874   화약
# 26394  KETI_SL_0000036875  화요일
# 26395  KETI_SL_0000036876  화장실
# 26396  KETI_SL_0000036877   화재
#
# [26397 rows x 2 columns]

# %%
import urllib.request
import json

# %%
#papago translation api
url = 'https://openapi.naver.com/v1/papago/n2mt'
client_id = 'w7qb8_wV1jeo3Mx7iMEg'
client_secret = 'CqEcD1gtTd'

source = 'ko'
target = 'en'

def translate(text):
    encText = urllib.parse.quote(text)
    data = f'source={source}&target={target}&text=' + encText
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()

    if (rescode == 200):
        response_body = response.read()
        decode = json.loads(response_body.decode('utf-8'))
        result = decode['message']['result']['translatedText']
        #print(result)
        return result
    else:
        print("Error Code:" + rescode)
        return "Error Code:" + rescode

# %%
# !pip install bidict
from bidict import bidict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bidict in c:\users\user\appdata\roaming\python\python39\site-packages (0.22.1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)

# %%
#데이터 레이블 한국어-영어 쌍 양방향 딕셔너리
annotation_bidict = bidict()

#데이터 프레임 행으로 순회
for idx, row in df.iterrows():
    key_kr = row['한국어']
    
    #한국어 단어 숫자인 경우
    #str으로 변환 후 그대로 value에 저장
    if str(type(key_kr)) == "<class 'int'>":
        annotation_bidict.forceput(str(key_kr), str(key_kr))
        
    #한국어 단어 string인 경우
    #영어로 번역하여 value에 저장
    if str(type(key_kr)) == "<class 'str'>":
        try:
            value_en = translate(key_kr)
            print(key_kr +": "+value_en)
        except:
            print("Error! key_kr = "+key_kr)
        else:
            annotation_bidict.forceput(key_kr, value_en)
    
print(annotation_bidict)
# Out:
# 가렵다: Itchy.
# 가스: Gas
# 가슴: Chest
# 가시: thorn
# 각목: each tree
# 갇히다: Be locked up.
# 감금: confinement
# 감전: an electric shock
# 강: River
# 강남구: Gangnam-gu
# 강동구: Gangdong-gu District
# 강북구: Gangbuk-gu District
# 강서구: Gangseo-gu
# 강풍: a strong wind
# 개: Dog
# 거실: The living room.
# 걸렸다: Got you
# 결박: a tie
# 경운기: cultivator
# 경찰: The police.
# 경찰차: a police car
# 계곡: Valley
# 계단: stairs
# 고속도로: an expressway
# 고압전선: a high-voltage cable
# 고열: a high fever
# 고장: Breakdown
# 부러지다: break off
# 골절: Fracture
# 탈골: dislocation
# 곰: Bear
# 공사장: a construction site
# 공원: a public park
# 놀이터: a playground
# 공장: factory
# 관악구: Gwanak District
# 광진구: Gwangjin-gu District
# 교통사고: a traffic accident
# 구급대: a first-aid unit
# 구급대원: a paramedic
# 구급차: ambulance
# 구로구: Guro District
# 구청: District office
# 구해주세요: Please save me
# 귀: Ear
# 금가다: be cracked
# 금요일: Friday
# 금천구: Geumcheon District
# 급류: a rapid current
# 기절: faint
# 기절하다: Faint.
# 깔리다: be laid down
# 끓는물: boiling water
# 남자친구: Boyfriend
# 남편: Husband
# 남학생: a boy student
# 납치: Kidnapping
# 낫: sickle
# 낯선남자: a strange man
# 낯선사람: Stranger
# 낯선여자: a strange woman
# 내년: Next year
# 내일: Tomorrow
# 냄새나다: to smell
# 노원구: Nowon District
# 논: rice paddies
# 농약: Pesticide
# 누나: older sister
# 누수: Leakage
# 누전: a short circuit
# 누출: Leakage
# 눈: Eyes
# 다리: Leg
# 다음: next
# 달(월): Month (Month)
# 대문앞: in front of the gate
# 도둑: thief
# 절도: theft
# 도로: Road
# 도봉구: Dobong District
# 독극물: a poison
# 독버섯: Poisonous mushroom
# 독사: a poisonous snake
# 동대문구: Dongdaemun-gu District
# 동생: Younger brother
# 동작구: Dongjak District
# 동전: a coin
# 두드러기생기다: have hives
# 뒤: Back
# 뒤통수: the back of the head
# 등: back
# 딸: daughter
# 떨어지다: fall off
# 쓰러지다: Collapse.
# 뜨거운물: hot water
# 마당: garden
# 마포구: Mapo-gu District
# 말려주세요: Please dry it
# 말벌: wasp
# 맹견: a fierce dog
# 머리: Head
# 멧돼지: Boar
# 목: Neck
# 목요일: Thursday
# 무너지다: Collapse.
# 붕괴: collapse
# 무릎: Knee
# 문틈: a crack in the door
# 물: Water
# 밑에: Under
# 아래: Below.
# 바다: the sea
# 반점생기다: get spots
# 발: Feet
# 발가락: Toes
# 발목: Ankle
# 발작: an attack
# 방망이: Bat
# 밭: Field
# 배: ship
# 복부: the abdomen
# 배고프다: I'm hungry
# 뱀: Snake
# 벌: Punishment
# 범람: Flooding
# 벼락: Lightning
# 병원: a hospital
# 보건소: Public health center
# 보내주세요(경찰): Let me go. (Police
# 보내주세요(구급차): Send it to me (Emergency Vehicle)
# 복통: a stomachache
# 볼: Ball
# 부엌: kitchen
# 불: Fire
# 불나다: catch fire
# 붕대: Bandage
# 비닐하우스: a green house
# 비상약: emergency medicine
# 빌라: Villa
# 뼈: bone
# 사이: between
# 산: Mountain
# 살충제: Pesticides
# 살해: Murder
# 삼키다: Swallow.
# 서대문구: Seodaemun District
# 서랍: Drawer
# 서울시: Seoul City
# 서초구: Seocho District
# 선반: Shelf
# 선생님: Teacher
# 성동구: Seongdong District
# 성북구: Seongbuk District
# 성폭행: sexual assault
# 소방관: Firefighter
# 소방차: fire truck
# 소화기: a fire extinguisher
# 소화전: a fire hydrant
# 손: Hands
# 손가락: Finger
# 손목: Wrist
# 송파구: Songpa-gu
# 수영장: a swimming pool
# 수요일: Wednesday
# 술취한 사람: a drunkard
# 숨을안쉬다: be out of breath
# 시청: City Hall
# 신고하세요(경찰): Call the police
# 심장마비: A heart attack.
# 아기: Baby
# 아이들: children
# 어린이: children
# 아내: Wife
# 아들: Son.
# 아빠: Dad.
# 아저씨: Uncle
# 아줌마: ma'am
# 아파트: apartment
# 인대: Ligament
# 안방: main room
# 알려주세요: Let me know.
# 앞: front
# 앞집: the house in front of one
# 약국: a drugstore
# 약사: a pharmacist
# 양천구: Yangcheon-gu District
# 어깨: Shoulder
# 어제: Yesterday
# 어지러움: Dizziness
# 언니: older sister
# 얼굴: Your face
# 엄마: Mom.
# 엘리베이터: Elevator
# 여자친구: GFRIEND
# 여학생: a schoolgirl
# 연기: smoke
# 연락해주세요: Please call me
# 열: Heat
# 열나다: have a fever
# 열어주세요: Please open it.
# 엽총: a shotgun
# 영등포구: Yeongdeungpo-gu District
# 옆집: the next door
# 옆집 아저씨: the man next door
# 옆집 할아버지: the grandfather next door
# 옆집사람: the next-door neighbor
# 옆쪽: the side
# 오늘: today
# 오른쪽: right
# 오른쪽-귀: right-ear
# 오른쪽-눈: right-eye
# 오빠: Older brother
# 옥상: roof
# 올해: This year
# 왼쪽: the left
# 왼쪽-귀: Left-Ear
# 왼쪽-눈: Left-Eye
# 욕실: Bathroom
# 용산구: Yongsan-gu District
# 우리집: Our house
# 운동장: a playground
# 월요일: Monday
# 위: Above
# 위에: On
# 위협: Threat
# 윗집: the upper house
# 윗집사람: one's superior
# 유리: Glass
# 유치원: kindergarten
# 유치원 버스: a kindergarten bus
# 은평구: Eunpyeong District
# 음식물: food and drink
# 응급대원: an emergency worker
# 응급처리: emergency treatment
# 의사: Doctor
# 이마: Forehead
# 이물질: Foreign substance
# 이번: This
# 이상한사람: a strange person
# 이웃집: a neighboring house
# 일요일: Sunday
# 임산부: Pregnant women
# 임신한아내: a pregnant wife
# 자동차: Car
# 자살: Suicide
# 자상: a cut
# 작년: Last year
# 작은방: a small room
# 장난감: Toy
# 장단지: a burial mound
# 절단: Disconnections
# 제초제: herbicide
# 조난: distress
# 종로구: Jongno-gu
# 주: Week
# 중구: Jung-gu
# 중랑구: Jungnang District
# 지난: Last
# 지혈대: a tourniquet
# 진통제: a painkiller
# 질식: suffocation
# 집: House
# 집단폭행: a mass assault
# 차밖: Out of the car
# 차안: inside the car
# 창문: Window
# 창백하다: be pale
# 체온계: Thermometer
# 총: Total
# 추락: fall
# 축사: a congratulatory address
# 출산: child birth
# 출혈: Bleeding
# 피나다: bleed
# 친구: Friend
# 침수: Inundation
# 칼: Knife
# 코: The nose
# 택시: a taxi
# 토요일: Saturday
# 토하다: Throw up.
# 통학버스: a school bus
# 트랙터: a tractor
# 트럭: Truck
# 파도: Wave.
# 파편: a fragment
# 팔: Arm
# 팔꿈치: Elbow
# 폭발: Explosion
# 폭탄: Bomb
# 폭우: Heavy rain
# 폭행: Assault
# 학교: School
# 학생: Student
# 할머니: Grandma.
# 할아버지: Grandfather
# 함몰되다: sink in
# 해(연): Sun (Yeon)
# 해독제: an antidote
# 해열제: fever reducer
# 허리: Waist
# 허벅지: thigh
# 현관: the front door
# 현관앞: in front of the front door
# 협박: threat
# 형: Brother
# 호흡곤란: shortness of breath
# 호흡기: the respiratory tract
# 홍수: Flood
# 화상: Burn
# 화약: gunpowder
# 화요일: Tuesday
# 화장실: Washroom.
# 화재: Fire
# 가렵다: Itchy.
# 가스: Gas
# 가슴: Chest
# 가시: thorn
# 각목: each tree
# 갇히다: Be locked up.
# 감금: confinement
# 감전: an electric shock
# 강: River
# 강남구: Gangnam-gu
# 강동구: Gangdong-gu District
# 강북구: Gangbuk-gu District
# 강서구: Gangseo-gu
# 강풍: a strong wind
# 개: Dog
# 거실: The living room.
# 걸렸다: Got you
# 결박: a tie
# 경운기: cultivator
# 경찰: The police.
# 경찰차: a police car
# 계곡: Valley
# 계단: stairs
# 고속도로: an expressway
# 고압전선: a high-voltage cable
# 고열: a high fever
# 고장: Breakdown
# 부러지다: break off
# 골절: Fracture
# 탈골: dislocation
# 곰: Bear
# 공사장: a construction site
# 공원: a public park
# 놀이터: a playground
# 공장: factory
# 관악구: Gwanak District
# 광진구: Gwangjin-gu District
# 교통사고: a traffic accident
# 구급대: a first-aid unit
# 구급대원: a paramedic
# 구급차: ambulance
# 구로구: Guro District
# 구청: District office
# 구해주세요: Please save me
# 귀: Ear
# 금가다: be cracked
# 금요일: Friday
# 금천구: Geumcheon District
# 급류: a rapid current
# 기절: faint
# 기절하다: Faint.
# 깔리다: be laid down
# 끓는물: boiling water
# 남자친구: Boyfriend
# 남편: Husband
# 남학생: a boy student
# 납치: Kidnapping
# 낫: sickle
# 낯선남자: a strange man
# 낯선사람: Stranger
# 낯선여자: a strange woman
# 내년: Next year
# 내일: Tomorrow
# 냄새나다: to smell
# 노원구: Nowon District
# 논: rice paddies
# 농약: Pesticide
# 누나: older sister
# 누수: Leakage
# 누전: a short circuit
# 누출: Leakage
# 눈: Eyes
# 다리: Leg
# 다음: next
# 달(월): Month (Month)
# 대문앞: in front of the gate
# 도둑: thief
# 절도: theft
# 도로: Road
# 도봉구: Dobong District
# 독극물: a poison
# 독버섯: Poisonous mushroom
# 독사: a poisonous snake
# 동대문구: Dongdaemun-gu District
# 동생: Younger brother
# 동작구: Dongjak District
# 동전: a coin
# 두드러기생기다: have hives
# 뒤: Back
# 뒤통수: the back of the head
# 등: back
# 딸: daughter
# 떨어지다: fall off
# Error! key_kr = 쓰러지다
# 뜨거운물: hot water
# 마당: garden
# 마포구: Mapo-gu District
# 말려주세요: Please dry it
# 말벌: wasp
# 맹견: a fierce dog
# 머리: Head
# 멧돼지: Boar
# 목: Neck
# 목요일: Thursday
# 무너지다: Collapse.
# 붕괴: collapse
# 무릎: Knee
# 문틈: a crack in the door
# 물: Water
# 밑에: Under
# 아래: Below.
# 바다: the sea
# 반점생기다: get spots
# 발: Feet
# 발가락: Toes
# 발목: Ankle
# 발작: an attack
# 방망이: Bat
# 밭: Field
# 배: ship
# 복부: the abdomen
# 배고프다: I'm hungry
# 뱀: Snake
# 벌: Punishment
# 범람: Flooding
# 벼락: Lightning
# 병원: a hospital
# 보건소: Public health center
# 보내주세요(경찰): Let me go. (Police
# 보내주세요(구급차): Send it to me (Emergency Vehicle)
# 복통: a stomachache
# 볼: Ball
# 부엌: kitchen
# 불: Fire
# 불나다: catch fire
# 붕대: Bandage
# 비닐하우스: a green house
# 비상약: emergency medicine
# 빌라: Villa
# 뼈: bone
# 사이: between
# 산: Mountain
# 살충제: Pesticides
# 살해: Murder
# 삼키다: Swallow.
# 서대문구: Seodaemun District
# 서랍: Drawer
# 서울시: Seoul City
# 서초구: Seocho District
# 선반: Shelf
# 선생님: Teacher
# 성동구: Seongdong District
# 성북구: Seongbuk District
# 성폭행: sexual assault
# 소방관: Firefighter
# 소방차: fire truck
# 소화기: a fire extinguisher
# 소화전: a fire hydrant
# 손: Hands
# 손가락: Finger
# 손목: Wrist
# 송파구: Songpa-gu
# 수영장: a swimming pool
# 수요일: Wednesday
# 술취한 사람: a drunkard
# 숨을안쉬다: be out of breath
# 시청: City Hall
# 신고하세요(경찰): Call the police
# 심장마비: A heart attack.
# 아기: Baby
# 아이들: children
# 어린이: children
# 아내: Wife
# 아들: Son.
# 아빠: Dad.
# 아저씨: Uncle
# 아줌마: ma'am
# 아파트: apartment
# 인대: Ligament
# 안방: main room
# 알려주세요: Let me know.
# 앞: front
# 앞집: the house in front of one
# 약국: a drugstore
# 약사: a pharmacist
# 양천구: Yangcheon-gu District
# 어깨: Shoulder
# 어제: Yesterday
# 어지러움: Dizziness
# 언니: older sister
# 얼굴: Your face
# 엄마: Mom.
# 엘리베이터: Elevator
# 여자친구: GFRIEND
# 여학생: a schoolgirl
# 연기: smoke
# 연락해주세요: Please call me
# 열: Heat
# 열나다: have a fever
# 열어주세요: Please open it.
# 엽총: a shotgun
# 영등포구: Yeongdeungpo-gu District
# 옆집: the next door
# 옆집 아저씨: the man next door
# 옆집 할아버지: the grandfather next door
# 옆집사람: the next-door neighbor
# 옆쪽: the side
# 오늘: today
# 오른쪽: right
# 오른쪽-귀: right-ear
# 오른쪽-눈: right-eye
# 오빠: Older brother
# 옥상: roof
# 올해: This year
# 왼쪽: the left
# 왼쪽-귀: Left-Ear
# 왼쪽-눈: Left-Eye
# 욕실: Bathroom
# 용산구: Yongsan-gu District
# 우리집: Our house
# 운동장: a playground
# 월요일: Monday
# 위: Above
# 위에: On
# 위협: Threat
# 윗집: the upper house
# 윗집사람: one's superior
# 유리: Glass
# 유치원: kindergarten
# 유치원 버스: a kindergarten bus
# 은평구: Eunpyeong District
# 음식물: food and drink
# 응급대원: an emergency worker
# 응급처리: emergency treatment
# Error! key_kr = 의사
# Error! key_kr = 이마
# Error! key_kr = 이물질
# Error! key_kr = 이번
# Error! key_kr = 이상한사람
# Error! key_kr = 이웃집
# Error! key_kr = 일요일
# Error! key_kr = 임산부
# Error! key_kr = 임신한아내
# Error! key_kr = 자동차
# Error! key_kr = 자살
# Error! key_kr = 자상
# Error! key_kr = 작년
# Error! key_kr = 작은방
# Error! key_kr = 장난감
# Error! key_kr = 장단지
# Error! key_kr = 절단
# Error! key_kr = 제초제
# Error! key_kr = 조난
# Error! key_kr = 종로구
# Error! key_kr = 주
# Error! key_kr = 중구
# Error! key_kr = 중랑구
# Error! key_kr = 지난
# Error! key_kr = 지혈대
# Error! key_kr = 진통제
# Error! key_kr = 질식
# Error! key_kr = 집
# Error! key_kr = 집단폭행
# Error! key_kr = 차밖
# Error! key_kr = 차안
# Error! key_kr = 창문
# Error! key_kr = 창백하다
# Error! key_kr = 체온계
# Error! key_kr = 총
# Error! key_kr = 추락
# Error! key_kr = 축사
# Error! key_kr = 출산
# Error! key_kr = 출혈
# Error! key_kr = 피나다
# Error! key_kr = 친구
# Error! key_kr = 침수
# Error! key_kr = 칼
# Error! key_kr = 코
# Error! key_kr = 택시
# Error! key_kr = 토요일
# Error! key_kr = 토하다
# Error! key_kr = 통학버스
# Error! key_kr = 트랙터
# Error! key_kr = 트럭
# Error! key_kr = 파도
# Error! key_kr = 파편
# Error! key_kr = 팔
# Error! key_kr = 팔꿈치
# Error! key_kr = 폭발
# Error! key_kr = 폭탄
# Error! key_kr = 폭우
# Error! key_kr = 폭행
# Error! key_kr = 학교
# Error! key_kr = 학생
# Error! key_kr = 할머니
# Error! key_kr = 할아버지
# Error! key_kr = 함몰되다
# Error! key_kr = 해(연)
# Error! key_kr = 해독제
# Error! key_kr = 해열제
# Error! key_kr = 허리
# Error! key_kr = 허벅지
# Error! key_kr = 현관
# Error! key_kr = 현관앞
# Error! key_kr = 협박
# Error! key_kr = 형
# Error! key_kr = 호흡곤란
# Error! key_kr = 호흡기
# Error! key_kr = 홍수
# Error! key_kr = 화상
# Error! key_kr = 화약
# Error! key_kr = 화요일
# Error! key_kr = 화장실
# Error! key_kr = 화재
# Error! key_kr = 가렵다
# Error! key_kr = 가스
# Error! key_kr = 가슴
# Error! key_kr = 가시
# Error! key_kr = 각목
# Error! key_kr = 갇히다
# Error! key_kr = 감금
# Error! key_kr = 감전
# Error! key_kr = 강
# Error! key_kr = 강남구
# Error! key_kr = 강동구
# Error! key_kr = 강북구
# Error! key_kr = 강서구
# Error! key_kr = 강풍
# Error! key_kr = 개
# Error! key_kr = 거실
# Error! key_kr = 걸렸다
# Error! key_kr = 결박
# Error! key_kr = 경운기
# Error! key_kr = 경찰
# Error! key_kr = 경찰차
# Error! key_kr = 계곡
# Error! key_kr = 계단
# Error! key_kr = 고속도로
# Error! key_kr = 고압전선
# Error! key_kr = 고열
# Error! key_kr = 고장
# Error! key_kr = 부러지다
# Error! key_kr = 골절
# Error! key_kr = 탈골
# Error! key_kr = 곰
# Error! key_kr = 공사장
# Error! key_kr = 공원
# Error! key_kr = 놀이터
# Error! key_kr = 공장
# Error! key_kr = 관악구
# Error! key_kr = 광진구
# Error! key_kr = 교통사고
# Error! key_kr = 구급대
# Error! key_kr = 구급대원
# Error! key_kr = 구급차
# Error! key_kr = 구로구
# Error! key_kr = 구청
# Error! key_kr = 구해주세요
# Error! key_kr = 귀
# Error! key_kr = 금가다
# Error! key_kr = 금요일
# Error! key_kr = 금천구
# Error! key_kr = 급류
# Error! key_kr = 기절
# Error! key_kr = 기절하다
# Error! key_kr = 깔리다
# Error! key_kr = 끓는물
# Error! key_kr = 남자친구
# Error! key_kr = 남편
# Error! key_kr = 남학생
# Error! key_kr = 납치
# Error! key_kr = 낫
# Error! key_kr = 낯선남자
# Error! key_kr = 낯선사람
# Error! key_kr = 낯선여자
# Error! key_kr = 내년
# Error! key_kr = 내일
# Error! key_kr = 냄새나다
# Error! key_kr = 노원구
# Error! key_kr = 논
# Error! key_kr = 농약
# Error! key_kr = 누나
# Error! key_kr = 누수
# Error! key_kr = 누전
# Error! key_kr = 누출
# Error! key_kr = 눈
# Error! key_kr = 다리
# Error! key_kr = 다음
# Error! key_kr = 달(월)
# Error! key_kr = 대문앞
# Error! key_kr = 도둑
# Error! key_kr = 절도
# Error! key_kr = 도로
# Error! key_kr = 도봉구
# Error! key_kr = 독극물
# Error! key_kr = 독버섯
# Error! key_kr = 독사
# Error! key_kr = 동대문구
# Error! key_kr = 동생
# Error! key_kr = 동작구
# Error! key_kr = 동전
# Error! key_kr = 두드러기생기다
# Error! key_kr = 뒤
# Error! key_kr = 뒤통수
# Error! key_kr = 등
# Error! key_kr = 딸
# Error! key_kr = 떨어지다
# Error! key_kr = 쓰러지다
# Error! key_kr = 뜨거운물
# Error! key_kr = 마당
# Error! key_kr = 마포구
# Error! key_kr = 말려주세요
# Error! key_kr = 말벌
# Error! key_kr = 맹견
# Error! key_kr = 머리
# Error! key_kr = 멧돼지
# Error! key_kr = 목
# Error! key_kr = 목요일
# Error! key_kr = 무너지다
# Error! key_kr = 붕괴
# Error! key_kr = 무릎
# Error! key_kr = 문틈
# Error! key_kr = 물
# Error! key_kr = 밑에
# Error! key_kr = 아래
# Error! key_kr = 바다
# Error! key_kr = 반점생기다
# Error! key_kr = 발
# Error! key_kr = 발가락
# Error! key_kr = 발목
# Error! key_kr = 발작
# Error! key_kr = 방망이
# Error! key_kr = 밭
# Error! key_kr = 배
# Error! key_kr = 복부
# Error! key_kr = 배고프다
# Error! key_kr = 뱀
# Error! key_kr = 벌
# Error! key_kr = 범람
# Error! key_kr = 벼락
# Error! key_kr = 병원
# Error! key_kr = 보건소
# Error! key_kr = 보내주세요(경찰)
# Error! key_kr = 보내주세요(구급차)
# Error! key_kr = 복통
# Error! key_kr = 볼
# Error! key_kr = 부엌
# Error! key_kr = 불
# Error! key_kr = 불나다
# Error! key_kr = 붕대
# Error! key_kr = 비닐하우스
# Error! key_kr = 비상약
# Error! key_kr = 빌라
# Error! key_kr = 뼈
# Error! key_kr = 사이
# Error! key_kr = 산
# Error! key_kr = 살충제
# Error! key_kr = 살해
# Error! key_kr = 삼키다
# Error! key_kr = 서대문구
# Error! key_kr = 서랍
# Error! key_kr = 서울시
# Error! key_kr = 서초구
# Error! key_kr = 선반
# Error! key_kr = 선생님
# Error! key_kr = 성동구
# Error! key_kr = 성북구
# Error! key_kr = 성폭행
# Error! key_kr = 소방관
# Error! key_kr = 소방차
# Error! key_kr = 소화기
# Error! key_kr = 소화전
# Error! key_kr = 손
# Error! key_kr = 손가락
# Error! key_kr = 손목
# Error! key_kr = 송파구
# Error! key_kr = 수영장
# Error! key_kr = 수요일
# Error! key_kr = 술취한 사람
# Error! key_kr = 숨을안쉬다
# Error! key_kr = 시청
# Error! key_kr = 신고하세요(경찰)
# Error! key_kr = 심장마비
# Error! key_kr = 아기
# Error! key_kr = 아이들
# Error! key_kr = 어린이
# Error! key_kr = 아내
# Error! key_kr = 아들
# Error! key_kr = 아빠
# Error! key_kr = 아저씨
# Error! key_kr = 아줌마
# Error! key_kr = 아파트
# Error! key_kr = 인대
# Error! key_kr = 안방
# Error! key_kr = 알려주세요
# Error! key_kr = 앞
# Error! key_kr = 앞집
# Error! key_kr = 약국
# Error! key_kr = 약사
# Error! key_kr = 양천구
# Error! key_kr = 어깨
# Error! key_kr = 어제
# Error! key_kr = 어지러움
# Error! key_kr = 언니
# Error! key_kr = 얼굴
# Error! key_kr = 엄마
# Error! key_kr = 엘리베이터
# Error! key_kr = 여자친구
# Error! key_kr = 여학생
# Error! key_kr = 연기
# Error! key_kr = 연락해주세요
# Error! key_kr = 열
# Error! key_kr = 열나다
# Error! key_kr = 열어주세요
# Error! key_kr = 엽총
# Error! key_kr = 영등포구
# Error! key_kr = 옆집
# Error! key_kr = 옆집 아저씨
# Error! key_kr = 옆집 할아버지
# Error! key_kr = 옆집사람
# Error! key_kr = 옆쪽
# Error! key_kr = 오늘
# Error! key_kr = 오른쪽
# Error! key_kr = 오른쪽-귀
# Error! key_kr = 오른쪽-눈
# Error! key_kr = 오빠
# Error! key_kr = 옥상
# Error! key_kr = 올해
# Error! key_kr = 왼쪽
# Error! key_kr = 왼쪽-귀
# Error! key_kr = 왼쪽-눈
# Error! key_kr = 욕실
# Error! key_kr = 용산구
# Error! key_kr = 우리집
# Error! key_kr = 운동장
# Error! key_kr = 월요일
# Error! key_kr = 위
# Error! key_kr = 위에
# Error! key_kr = 위협
# Error! key_kr = 윗집
# Error! key_kr = 윗집사람
# Error! key_kr = 유리
# Error! key_kr = 유치원
# Error! key_kr = 유치원 버스
# Error! key_kr = 은평구
# Error! key_kr = 음식물
# Error! key_kr = 응급대원
# Error! key_kr = 응급처리
# Error! key_kr = 의사
# Error! key_kr = 이마
# Error! key_kr = 이물질
# Error! key_kr = 이번
# Error! key_kr = 이상한사람
# Error! key_kr = 이웃집
# Error! key_kr = 일요일
# Error! key_kr = 임산부
# Error! key_kr = 임신한아내
# Error! key_kr = 자동차
# Error! key_kr = 자살
# Error! key_kr = 자상
# Error! key_kr = 작년
# Error! key_kr = 작은방
# Error! key_kr = 장난감
# Error! key_kr = 장단지
# Error! key_kr = 절단
# Error! key_kr = 제초제
# Error! key_kr = 조난
# Error! key_kr = 종로구
# Error! key_kr = 주
# Error! key_kr = 중구
# Error! key_kr = 중랑구
# Error! key_kr = 지난
# Error! key_kr = 지혈대
# Error! key_kr = 진통제
# Error! key_kr = 질식
# Error! key_kr = 집
# Error! key_kr = 집단폭행
# Error! key_kr = 차밖
# Error! key_kr = 차안
# Error! key_kr = 창문
# Error! key_kr = 창백하다
# Error! key_kr = 체온계
# Error! key_kr = 총
# Error! key_kr = 추락
# Error! key_kr = 축사
# Error! key_kr = 출산
# Error! key_kr = 출혈
# Error! key_kr = 피나다
# Error! key_kr = 친구
# Error! key_kr = 침수
# Error! key_kr = 칼
# Error! key_kr = 코
# Error! key_kr = 택시
# Error! key_kr = 토요일
# Error! key_kr = 토하다
# Error! key_kr = 통학버스
# Error! key_kr = 트랙터
# Error! key_kr = 트럭
# Error! key_kr = 파도
# Error! key_kr = 파편
# Error! key_kr = 팔
# Error! key_kr = 팔꿈치
# Error! key_kr = 폭발
# Error! key_kr = 폭탄
# Error! key_kr = 폭우
# Error! key_kr = 폭행
# Error! key_kr = 학교
# Error! key_kr = 학생
# Error! key_kr = 할머니
# Error! key_kr = 할아버지
# Error! key_kr = 함몰되다
# Error! key_kr = 해(연)
# Error! key_kr = 해독제
# Error! key_kr = 해열제
# Error! key_kr = 허리
# Error! key_kr = 허벅지
# Error! key_kr = 현관
# Error! key_kr = 현관앞
# Error! key_kr = 협박
# Error! key_kr = 형
# Error! key_kr = 호흡곤란
# Error! key_kr = 호흡기
# Error! key_kr = 홍수
# Error! key_kr = 화상
# Error! key_kr = 화약
# Error! key_kr = 화요일
# Error! key_kr = 화장실
# Error! key_kr = 화재
# Error! key_kr = 가렵다
# Error! key_kr = 가스
# Error! key_kr = 가슴
# Error! key_kr = 가시
# Error! key_kr = 각목
# Error! key_kr = 갇히다
# Error! key_kr = 감금
# Error! key_kr = 감전
# Error! key_kr = 강
# Error! key_kr = 강남구
# Error! key_kr = 강동구
# Error! key_kr = 강북구
# Error! key_kr = 강서구
# Error! key_kr = 강풍
# Error! key_kr = 개
# Error! key_kr = 거실
# Error! key_kr = 걸렸다
# Error! key_kr = 결박
# Error! key_kr = 경운기
# Error! key_kr = 경찰
# Error! key_kr = 경찰차
# Error! key_kr = 계곡
# Error! key_kr = 계단

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data_KSL_Entire_DataSet') 

#num of videos
no_sequences = 60

# 1 Video = 60 frames
sequence_length = 50
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Path for exported data, numpy arrays
# ----> 2 DATA_PATH = os.path.join('MP_Data_KSL_FinalPresentation')
#       4 # Actions that we try to detect
#       5 #actions = np.array(['stranger', 'car_accident', 'down', 'house', 'fire', 'is_on_fire'])
#       6 #actions = np.array(['house', 'thief', 'outofbreath', 'down', 'fire', 'stranger', 'car_accident'])
#       7
#       8 #num of videos
#       9 no_sequences = 60
#
# NameError: name 'os' is not defined

# %%
for action in actions: #make directory for each actions
    for sequence in range(no_sequences): #make directory for each videos per action
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 for action in actions: #make directory for each actions
#       2     for sequence in range(no_sequences): #make directory for each videos per action
#       3         try:
#
# NameError: name 'actions' is not defined

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
##extract keypoints from video
def frame_capture(action, sequence, video):
    cap = cv2.VideoCapture(video)
    
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        frame_num = 0
        while cap.isOpened():
            # Read feed
            ret, frame = cap.read()
            if ret == False:
                break
                
            # Make detections
            image, results = mediapipe_detection(frame, holistic)  
            # Draw landmarks
            draw_styled_landmarks(image, results)

            # Show to screen
            cv2.imshow('OpenCV Video', image)

            # export keypoints
            keypoints = extract_keypoints(results) #results of frame -> numpy array
            npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
            np.save(npy_path, keypoints) #save numpy array in directory
            
            #increase frame_num
            frame_num = frame_num + 1
                
            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                
        cap.release()
        cv2.destroyAllWindows()

# %%
curDir = "C:/Users/User/Desktop/SCHOOL/2023-1/졸업 프로젝트/수어 데이터셋/최종 발표용/교통사고"
curAction = "accident"
curSequence = 0
for file in os.listdir(curDir):
    if(file.endswith(".mp4")):
        path = os.path.join(curDir, file)
        frame_capture(curAction, curSequence, path)
        curSequence = curSequence + 1

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'house': 0,
#  'thief': 1,
#  'outofbreath': 2,
#  'down': 3,
#  'fire': 4,
#  'stranger': 5,
#  'car_accident': 6}

# %%
import fnmatch #폴더 안에 있는 npy 개수 계산하기 위함

#create two blank arrays
sequences, labels = [], [] 
#sequences(=videos) = feature data = x data 
#labels = label data = y data

for action in actions: 
    for sequence in range(no_sequences): #each action has 60 sequences(=videos)
        window = []
        
        #폴더 안에 있는 npy 개수(= frame 수) 계산
        file_count = len(fnmatch.filter(os.listdir(os.path.join(DATA_PATH, action, str(sequence))), '*.npy'))
        
        #저장된 npy 수가 원하는 sequence_length보다 같거나 많을 경우
        if(file_count >= sequence_length):  
            #앞에 있는 npy 버리고, start부터 끝까지 sequence_length개의 npy 가져오기
            start = file_count - sequence_length
            for frame_num in range(sequence_length):
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(start + frame_num)))
                window.append(res)
        #저장된 npy 수가 원하는 sequence_length보다 적을 경우
        else:
            #앞에 0으로 채운 npy 추가하기
            for frame_num in range(sequence_length - file_count):
                res = np.zeros(258) #132 + 63 + 63
                window.append(res)
            for frame_num in range(file_count):
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
                window.append(res)
                              
        #map label
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
X.shape

# %%
y = to_categorical(labels).astype(int) 
#converted label from int to binary array
#1 -> [1,0,0], 2 -> [0,1,0], 3 -> [0,0,1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
#split x,y data into train data and test data
#train data 95%, test data size 5%

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
#tensor board is used to monitor neural network training and it's accuracy

# %%
#build neural network architecture
model = Sequential()

#add 3 lstm layers
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(50,258)))
#64 lstm units, set return_sequences = true to stack lstm layers together
#input shape = 120 frames per prediction * 258 keypoints per frame 
model.add(LSTM(128, return_sequences=True, activation='relu'))
#128 lstm units, set return_sequences = true
model.add(LSTM(64, return_sequences=False, activation='relu'))
#64 lstm units, set return_sequences = false (means end of lstm layers)

#add 3 dense layers (dense = fully connected neural network)
model.add(Dense(64, activation='relu'))
#64 dense units
model.add(Dense(32, activation='relu'))
#32 dense units
model.add(Dense(actions.shape[0], activation='softmax'))
#activation function =  softmax (return values within 0~1, make sum of all values added up to 1)
#actions.shape[0] (=size of actions) = 3 (hello, thanks, iloveyou)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])

# %%
model.summary()

# %% [markdown]
# # 8. Make Predictions

# %%
predict_res = model.predict(X_test)

# %%
#y_test의 값은 각 label에 해당할 확률 값 ex.[0.1, 0.2, 0.7]
#y_test의 값이 가리키는 label 값 = 가장 큰 값을 가진 값
actions[np.argmax(predict_res[3])]

# %%
#y_test의 값은 binary array 형식 ex.[0, 0, 1]
#y_test의 값이 가리키는 label 값 = 1을 가진 값
actions[np.argmax(y_test[3])]

# %% [markdown]
# # 9. Save Weights

# %%
#단일 file/folder 에 모델의 아키텍처, 가중치 및 훈련 구성을 저장
model.save('kslaction.h5')

# %%
del model

# %%
model.load_weights('kslaction_50_frame.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
#y_test의 값들이 가리키는 label들을 하나의 리스트로 변환
#ex. [[0, 0, 1], [0, 1, 0]] -> [2, 1]
ytrue = np.argmax(y_test, axis=1).tolist()
#yhat의 값들이 가리키는 label들을 하나의 리스트로 변환
#ex. [[0.1, 0.2, 0.7], [0.1, 0.8, 0.1]] -> [2, 1]
yhat = np.argmax(yhat, axis=1).tolist()

# %%
#returns a confusion matrix sorted by the label order
multilabel_confusion_matrix(ytrue, yhat)

# %%
accuracy_score(ytrue, yhat)

# %% [markdown]
# # 11. Test in Real Time

# %%
actions_korean = ['집', '도둑', '숨이 안쉬어져요', '아래', '불이 났어요', '낯선사람', '교통사고']

# %%
#한글 텍스트 출력
from PIL import ImageFont, ImageDraw, Image

def putKoreanText(src, text, pos, font_size, font_color):
    img_pil = Image.fromarray(src)
    draw = ImageDraw.Draw(img_pil)
    font = ImageFont.truetype('C:/Users/User/ActionDetectionforSignLanguage/fonts/gulim.ttc', font_size)
    draw.text(pos, text, font=font, fill= font_color)
    return np.array(img_pil)

# %%
# 1. detection variables
sequence = [] #collect 60 frames to make a sequence(=video)
sentence = [] #concatenate history of predictions together
threshold = 0.7


cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-50:] #generate sequence with last 30 frames
        
        if len(sequence) == 50:
            #sequence.shape = (60, 1662)
            #the input shape model expects = (number of sequences, 60, 1662)
            res = model.predict(np.expand_dims(sequence, axis=0))[0] #predict one sequence at a time
            print(actions[np.argmax(res)])
            
            #3. Rendering logic
            #ex. res = [0.1, 0.2, 0.7]
            #np.argmax(res) = 2, res[np.argmax(res)] = 0.7
            if res[np.argmax(res)] > threshold: 
                cur_action_korean = actions_korean[np.argmax(res)]
                
                if len(sentence) > 0: 
                    #sentence에 저장된 prediction이 있는 경우 
                    #새로운 prediction인 경우에만 sentence에 추가
                    if cur_action_korean != sentence[-1]:
                        sentence.append(cur_action_korean)
                else: 
                    #sentence에 저장된 prediction 없는 경우 바로 sentence에 추가
                    sentence.append(cur_action_korean)
            
            #sentence가 너무 길어지지 않도록 마지막 5개의 prediction만 유지
            if len(sentence) > 5: 
                sentence = sentence[-5:]

            #Visualize probabilities
            #image = prob_viz(res, actions, image, colors)
            
            #cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
            cv2.rectangle(image, (0,0), (640, 40), (0, 0, 0), -1) 
            
            #cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
            #putKoreanText(src, text, pos, font_size, font_color
            image = putKoreanText(image, ' '.join(sentence), (3,10), 20, (255, 255, 255))
            
           
            # Show to screen
            cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 1s 673ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# fire

# %%
# prediction using video
def video_prediction(video):
    
    # 1. detection variables
    sequence = [] #collect 60 frames to make a sequence(=video)
    sentence = [] #concatenate history of predictions together
    threshold = 0.7

    cap = cv2.VideoCapture(video)
    
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            # Read video
            ret, frame = cap.read()
            if ret == False:
                break
                
            # Make detections
            image, results = mediapipe_detection(frame, holistic)
            print(results)
            # Draw landmarks
            draw_styled_landmarks(image, results)

            # 2. Prediction logic
            keypoints = extract_keypoints(results)
            sequence.append(keypoints)
            sequence = sequence[-60:] #generate sequence with last 30 frames

            if len(sequence) == 60:
                #sequence.shape = (60, 1662)
                #the input shape model expects = (number of sequences, 60, 1662)
                res = model.predict(np.expand_dims(sequence, axis=0))[0] #predict one sequence at a time
                print(actions[np.argmax(res)])

                #3. Rendering logic
                #ex. res = [0.1, 0.2, 0.7]
                #np.argmax(res) = 2, res[np.argmax(res)] = 0.7
                if res[np.argmax(res)] > threshold: 
                    cur_action_korean = actions_korean[np.argmax(res)]

                    if len(sentence) > 0: 
                        #sentence에 저장된 prediction이 있는 경우 
                        #새로운 prediction인 경우에만 sentence에 추가
                        if cur_action_korean != sentence[-1]:
                            sentence.append(cur_action_korean)
                    else: 
                        #sentence에 저장된 prediction 없는 경우 바로 sentence에 추가
                        sentence.append(cur_action_korean)

                #sentence가 너무 길어지지 않도록 마지막 5개의 prediction만 유지
                if len(sentence) > 5: 
                    sentence = sentence[-5:]

                #Visualize probabilities
                #image = prob_viz(res, actions, image, colors)

                #cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
                cv2.rectangle(image, (0,0), (640, 40), (0, 0, 0), -1) 

                #cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)

                #putKoreanText(src, text, pos, font_size, font_color
                image = putKoreanText(image, ' '.join(sentence), (3,10), 20, (255, 255, 255))


                # Show to screen
                cv2.imshow('Video Prediction', image)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                
        cap.release()
        cv2.destroyAllWindows()

# %%
curDir = "C:/Users/User/Desktop/SCHOOL/2023-1/졸업 프로젝트/수어 데이터셋/최종 발표용/아랫집에불이났어요"
for file in os.listdir(curDir):
    if(file.endswith(".mp4")):
        path = os.path.join(curDir, file)
        video_prediction(path)
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# outofbreath
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# stranger
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# house
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thief
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# car_accident
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 44ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# fire
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 5
#       3 if(file.endswith(".mp4")):
#       4     path = os.path.join(curDir, file)
# ----> 5     video_prediction(path)
#
# Cell In[43], line 20, in video_prediction(video)
#      17     break
#      19 # Make detections
# ---> 20 image, results = mediapipe_detection(frame, holistic)
#      21 print(results)
#      22 # Draw landmarks
#
# Cell In[4], line 6, in mediapipe_detection(image, model)
#       4 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR -> RGB
#       5 image.flags.writeable = False                  # Image is no longer writeable
# ----> 6 results = model.process(image)                 # Make prediction
#       7 image.flags.writeable = True                   # Image is now writeable
#       8 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB -> BGR
#
# File C:\ProgramData\anaconda3\envs\tf\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File C:\ProgramData\anaconda3\envs\tf\lib\site-packages\mediapipe\python\solution_base.py:365, in SolutionBase.process(self, input_data)
#     359   else:
#     360     self._graph.add_packet_to_input_stream(
#     361         stream=stream_name,
#     362         packet=self._make_packet(input_stream_type,
#     363                                  data).at(self._simulated_timestamp))
# --> 365 self._graph.wait_until_idle()
#     366 # Create a NamedTuple object where the field names are mapping to the graph
#     367 # output stream names.
#     368 solution_outputs = collections.namedtuple(
#     369     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
