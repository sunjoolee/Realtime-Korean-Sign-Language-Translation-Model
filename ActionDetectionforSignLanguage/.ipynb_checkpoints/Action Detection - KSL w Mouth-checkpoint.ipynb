# %% [markdown]
# # 1. Import and Install Dependencies

# %%
#!pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib
# !pip install opencv-python mediapipe scikit-learn matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\envs\tf\lib\site-packages (4.7.0.72)
# Requirement already satisfied: mediapipe in c:\programdata\anaconda3\envs\tf\lib\site-packages (0.10.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\envs\tf\lib\site-packages (1.2.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\tf\lib\site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from opencv-python) (1.24.3)
# Requirement already satisfied: absl-py in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (23.5.9)
# Requirement already satisfied: opencv-contrib-python in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (4.7.0.72)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\envs\tf\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\envs\tf\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\programdata\anaconda3\envs\tf\lib\site-packages)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model): 
    #image = feed frame
    #model = Holistic model
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR -> RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB -> BGR
    return image, results

# %%
#connection_drawing_spec 커스텀 (optional)
def draw_styled_landmarks(image, results):
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# # 3. Extract Keypoint Values
# results의 landmarks값 -> numpy array로 변환하기

# %%
def extract_keypoints(results):
    #result의 landmarks의 모든 key point values -> 하나의 numpy array 로 flatten
    #if landmarks has no value, fill numpy array with zero
    if results.pose_landmarks: #pose landmarks
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() 
    else:
        pose = np.zeros(132) #33*4

    if results.left_hand_landmarks: #left hand landmarks
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() 
    else:
        lh = np.zeros(63) #21*3

    if results.right_hand_landmarks: #right hand landmarks
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() 
    else:
        rh = np.zeros(63) #21*3
    
    return np.concatenate([pose, lh, rh])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data_KSL') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

#num of videos
no_sequences = 30

# 1 Video = 30 frames
sequence_length = 30

# %%
for action in actions: #make directory for each actions
    for sequence in range(no_sequences): #make directory for each videos per action
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()
                # Make detections
                image, results = mediapipe_detection(frame, holistic)
                #print(results)
                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    #output text to screen
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2500) #wait 2seconds
                    
                else: 
                    #output text to screen
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results) #results of frame -> numpy array
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints) #save numpy array in directory

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
#for cap release
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}
#{'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
#create two blank arrays
sequences, labels = [], [] 
#sequences(=videos) = feature data = x data 
#labels = label data = y data

for action in actions: #actions = hello, thanks, iloveyou
    for sequence in range(no_sequences): #each action has 30 sequences(=videos)
        window = []
        for frame_num in range(sequence_length): #each sequence(=video) has 30 frames
            #each frame has a numpy array that represents the keypoint of the frame
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        
        #map label
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int) 
#converted label from int to binary array
#1 -> [1,0,0], 2 -> [0,1,0], 3 -> [0,0,1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
#split x,y data into train data and test data
#train data 95%, test data size 5%

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
#tensor board is used to monitor neural network training and it's accuracy

# %%
#build neural network architecture
model = Sequential()

#add 3 lstm layers
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,258)))
#64 lstm units, set return_sequences = true to stack lstm layers together
#input shape = 30 frames per prediction * 258 keypoints per frame 
model.add(LSTM(128, return_sequences=True, activation='relu'))
#128 lstm units, set return_sequences = true
model.add(LSTM(64, return_sequences=False, activation='relu'))
#64 lstm units, set return_sequences = false (means end of lstm layers)

#add 3 dense layers (dense = fully connected neural network)
model.add(Dense(64, activation='relu'))
#64 dense units
model.add(Dense(32, activation='relu'))
#32 dense units
model.add(Dense(actions.shape[0], activation='softmax'))
#activation function =  softmax (return values within 0~1, make sum of all values added up to 1)
#actions.shape[0] (=size of actions) = 3 (hello, thanks, iloveyou)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
#optimizer function 원하는 것으로 변경 가능

#loss function 변경 불가능 
#multi-class classification model을 사용할 때는 loss function 반드시 categorical_crossentropy 사용해야
#binary-class classification model을 사용할 때는 loss function 반드시 binary_crossentropy 사용해야

#metrics 생략 가능
#metrics로 model의 accuracy tracking 가능

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 4s 60ms/step - loss: 1.1393 - categorical_accuracy: 0.3294
# Epoch 2/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0561 - categorical_accuracy: 0.3294
# Epoch 3/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.9285 - categorical_accuracy: 0.5765
# Epoch 4/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4088 - categorical_accuracy: 0.5529
# Epoch 5/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0756 - categorical_accuracy: 0.3647
# Epoch 6/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.9456 - categorical_accuracy: 0.6353
# Epoch 7/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.8380 - categorical_accuracy: 0.5882
# Epoch 8/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.6740 - categorical_accuracy: 0.5765
# Epoch 9/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3558 - categorical_accuracy: 0.7529
# Epoch 10/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.7911 - categorical_accuracy: 0.7765
# Epoch 11/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9215 - categorical_accuracy: 0.6118
# Epoch 12/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.8014 - categorical_accuracy: 0.6706
# Epoch 13/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.8776 - categorical_accuracy: 0.6588
# Epoch 14/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.8604 - categorical_accuracy: 0.5882
# Epoch 15/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.7622 - categorical_accuracy: 0.7059
# Epoch 16/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.4879 - categorical_accuracy: 0.8706
# Epoch 17/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.2669 - categorical_accuracy: 0.8706
# Epoch 18/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0588 - categorical_accuracy: 0.9882
# Epoch 19/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0377 - categorical_accuracy: 1.0000
# Epoch 20/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 21/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 22/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 23/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0069 - categorical_accuracy: 1.0000
# Epoch 24/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.5849e-04 - categorical_accuracy: 1.0000
# Epoch 25/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.2316e-04 - categorical_accuracy: 1.0000
# Epoch 26/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.1026 - categorical_accuracy: 0.9647
# Epoch 27/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 28/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0358 - categorical_accuracy: 0.9882
# Epoch 29/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0249 - categorical_accuracy: 0.9882
# Epoch 30/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 31/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0211 - categorical_accuracy: 1.0000
# Epoch 32/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0085 - categorical_accuracy: 1.0000
# Epoch 33/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.6729e-04 - categorical_accuracy: 1.0000
# Epoch 34/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0062 - categorical_accuracy: 1.0000
# Epoch 35/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.4329e-04 - categorical_accuracy: 1.0000
# Epoch 36/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1677e-04 - categorical_accuracy: 1.0000
# Epoch 37/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 4.2940e-04 - categorical_accuracy: 1.0000
# Epoch 38/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 7.9942e-04 - categorical_accuracy: 1.0000
# Epoch 39/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 5.6378e-04 - categorical_accuracy: 1.0000
# Epoch 40/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.9970e-04 - categorical_accuracy: 1.0000
# Epoch 41/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 3.4586e-05 - categorical_accuracy: 1.0000
# Epoch 42/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1525e-05 - categorical_accuracy: 1.0000
# Epoch 43/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.6871e-06 - categorical_accuracy: 1.0000
# Epoch 44/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 4.5720e-07 - categorical_accuracy: 1.0000
# Epoch 45/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.5567e-07 - categorical_accuracy: 1.0000
# Epoch 46/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 7.5733e-08 - categorical_accuracy: 1.0000
# Epoch 47/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 3.6464e-08 - categorical_accuracy: 1.0000
# Epoch 48/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.8232e-08 - categorical_accuracy: 1.0000
# Epoch 49/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1220e-08 - categorical_accuracy: 1.0000
# Epoch 50/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 8.4148e-09 - categorical_accuracy: 1.0000
# Epoch 51/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 7.0123e-09 - categorical_accuracy: 1.0000
# Epoch 52/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 5.6098e-09 - categorical_accuracy: 1.0000
# Epoch 53/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 4.2074e-09 - categorical_accuracy: 1.0000
# Epoch 54/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 55/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 56/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 57/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 58/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 59/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 60/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 61/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 62/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 63/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 64/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 65/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 66/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 67/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 68/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 69/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 70/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 71/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 72/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 73/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 74/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 75/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 76/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 77/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 78/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 79/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 80/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 81/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 82/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 83/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 84/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 85/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 86/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 87/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 88/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 2.8049e-09 - categorical_accuracy: 1.0000
# Epoch 89/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 90/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 91/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 92/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 93/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 94/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 95/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 96/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 97/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 98/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 99/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 100/1000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 101/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 102/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 103/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 104/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 105/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 106/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 107/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 108/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 109/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 110/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 111/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 112/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 113/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 114/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 115/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 116/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 117/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 118/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 119/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 120/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 121/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 122/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 123/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 124/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 125/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 126/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 127/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 128/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 129/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 130/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 131/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 132/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 133/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 134/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 135/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 136/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 137/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 138/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 139/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 140/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 141/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 142/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 143/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 144/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 145/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 146/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 147/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 148/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 149/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 150/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 151/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 152/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 153/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 154/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 155/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 156/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 157/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 158/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 159/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 160/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 161/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 162/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 163/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 164/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 165/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 166/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 167/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 168/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 169/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 170/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 171/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 172/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 173/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 174/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 175/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 176/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 177/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 178/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 179/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 180/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 181/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 182/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 183/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 184/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 185/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 186/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 187/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 188/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 189/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 190/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 191/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 192/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 193/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 194/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 195/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 196/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 197/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 198/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 199/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 200/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 201/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 202/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 203/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 204/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 205/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 206/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 207/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 208/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 209/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 210/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 211/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 212/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 213/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 214/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 215/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 216/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 217/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 218/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 219/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 220/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 221/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 222/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 223/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 224/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 225/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 226/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 227/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 228/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 229/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 230/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 231/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 232/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 233/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 234/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 235/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 236/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 237/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 238/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 239/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 240/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 241/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 242/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 243/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 244/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 245/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 246/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 247/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 248/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 249/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 250/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 251/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 252/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 253/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 254/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 255/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 256/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 257/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 258/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 259/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 260/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 261/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 262/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 263/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 264/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 265/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 266/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 267/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 268/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 269/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 270/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 271/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 272/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 273/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 274/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 275/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 276/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 277/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 278/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 279/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 280/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 281/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 282/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 283/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 284/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 285/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 286/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 287/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 288/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 289/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 290/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 291/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 292/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 293/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 294/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 295/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 296/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 297/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 298/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 299/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 300/1000
# 3/3 [==============================] - 0s 47ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 301/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 302/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 303/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 304/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 305/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 306/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 307/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 308/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 309/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 310/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 311/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 312/1000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 313/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 314/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 315/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 316/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 317/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 318/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 319/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 320/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 321/1000
# 3/3 [==============================] - 0s 48ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 322/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 323/1000
# 3/3 [==============================] - 0s 74ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 324/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 325/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 326/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 327/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 328/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 329/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 330/1000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 331/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 332/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 333/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 334/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 335/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 336/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 337/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 338/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 339/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 340/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 341/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 342/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 343/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 344/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 345/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 346/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 347/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 348/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 349/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 350/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 351/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 352/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 353/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 354/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 355/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 356/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 357/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 358/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 359/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 360/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 361/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 362/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 363/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 364/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 365/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 366/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 367/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 368/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 369/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 370/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 371/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 372/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 373/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 374/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 375/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 376/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 377/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 378/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 379/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 380/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 381/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 382/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 383/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 384/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 385/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 386/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 387/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 388/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 389/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 390/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 391/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 392/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 393/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 394/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 395/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 396/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 397/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 398/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 399/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 400/1000
# 3/3 [==============================] - 0s 49ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 401/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 402/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 403/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 404/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 405/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 406/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 407/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 408/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 409/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 410/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 411/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 412/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.4025e-09 - categorical_accuracy: 1.0000
# Epoch 413/1000
# ...
# Epoch 865/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 866/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 867/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 868/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 869/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 870/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 871/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 872/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 873/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 874/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 875/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 876/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 877/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 878/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 879/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 880/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 881/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 882/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 883/1000
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 884/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 885/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 886/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 887/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 888/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 889/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 890/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 891/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 892/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 893/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 894/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 895/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 896/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 897/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 898/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 899/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 900/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 901/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 902/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 903/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 904/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 905/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 906/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 907/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 908/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 909/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 910/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 911/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 912/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 913/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 914/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 915/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 916/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 917/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 918/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 919/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 920/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 921/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 922/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 923/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 924/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 925/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 926/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 927/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 928/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 929/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 930/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 931/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 932/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 933/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 934/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 935/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 936/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 937/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 938/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 939/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 940/1000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 941/1000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 942/1000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 943/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 944/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 945/1000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 946/1000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 947/1000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 948/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 949/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 950/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 951/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 952/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 953/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 954/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 955/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 956/1000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 957/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 958/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 959/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 960/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 961/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 962/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 963/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 964/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 965/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 966/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 967/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 968/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 969/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 970/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 971/1000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 972/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 973/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 974/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 975/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 976/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 977/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 978/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 979/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 980/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 981/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 982/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 983/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 984/1000
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 985/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 986/1000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 987/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 988/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 989/1000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 990/1000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 991/1000
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 992/1000
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 993/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 994/1000
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 995/1000
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 996/1000
# 3/3 [==============================] - 0s 57ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 997/1000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 998/1000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 999/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1000/1000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30, 64)            82688
#
#  lstm_4 (LSTM)               (None, 30, 128)           98816
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 237,251
# Trainable params: 237,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
predict_res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 609ms/step

# %%
#y_test의 값은 각 label에 해당할 확률 값 ex.[0.1, 0.2, 0.7]
#y_test의 값이 가리키는 label 값 = 가장 큰 값을 가진 값
actions[np.argmax(predict_res[3])]
# Out:
# 'thanks'

# %%
#y_test의 값은 binary array 형식 ex.[0, 0, 1]
#y_test의 값이 가리키는 label 값 = 1을 가진 값
actions[np.argmax(y_test[3])]
# Out:
# 'hello'

# %% [markdown]
# # 9. Save Weights

# %%
#단일 file/folder 에 모델의 아키텍처, 가중치 및 훈련 구성을 저장
model.save('kslaction.h5')

# %%
del model

# %%
model.load_weights('kslaction.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 45ms/step

# %%
#y_test의 값들이 가리키는 label들을 하나의 리스트로 변환
#ex. [[0, 0, 1], [0, 1, 0]] -> [2, 1]
ytrue = np.argmax(y_test, axis=1).tolist()
#yhat의 값들이 가리키는 label들을 하나의 리스트로 변환
#ex. [[0.1, 0.2, 0.7], [0.1, 0.8, 0.1]] -> [2, 1]
yhat = np.argmax(yhat, axis=1).tolist()

# %%
#returns a confusion matrix sorted by the label order
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[3, 0],
#         [1, 1]],
#
#        [[2, 1],
#         [0, 2]],
#
#        [[4, 0],
#         [0, 1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8

# %% [markdown]
# # 11. Test in Real Time

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = [] #collect 30 frames to make a sequence(=video)
sentence = [] #concatenate history of predictions together
threshold = 0.5

cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:] #generate sequence with last 30 frames
        
        if len(sequence) == 30:
            #sequence.shape = (30, 1662)
            #the input shape model expects = (number of sequences, 30, 1662)
            res = model.predict(np.expand_dims(sequence, axis=0))[0] #predict one sequence at a time
            print(actions[np.argmax(res)])
            
            #3. Rendering logic
            #ex. res = [0.1, 0.2, 0.7]
            #np.argmax(res) = 2, res[np.argmax(res)] = 0.7
            if res[np.argmax(res)] > threshold: 
                
                if len(sentence) > 0: 
                    #sentence에 저장된 prediction이 있는 경우 
                    #새로운 prediction인 경우에만 sentence에 추가
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else: 
                    #sentence에 저장된 prediction 없는 경우 바로 sentence에 추가
                    sentence.append(actions[np.argmax(res)])
            
            #sentence가 너무 길어지지 않도록 마지막 5개의 prediction만 유지
            if len(sentence) > 5: 
                sentence = sentence[-5:]

            #Visualize probabilities
            image = prob_viz(res, actions, image, colors)
            
            cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
            cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
            # Show to screen
            cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 22ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 45ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 31ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 23ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 47ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 24ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 26ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 25ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 32ms/step
# thanks
